# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
train=pd.read_csv('train.csv')
train
# Out:
#           id  person_age  person_income person_home_ownership  \
# 0          0          37          35000                  RENT
# 1          1          22          56000                   OWN
# 2          2          29          28800                   OWN
# 3          3          30          70000                  RENT
# 4          4          22          60000                  RENT
# ...      ...         ...            ...                   ...
# 58640  58640          34         120000              MORTGAGE
# 58641  58641          28          28800                  RENT
# 58642  58642          23          44000                  RENT
# 58643  58643          22          30000                  RENT
# 58644  58644          31          75000              MORTGAGE
#
#        person_emp_length loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0                    0.0   EDUCATION          B       6000          11.49
# ...

# %%
test=pd.read_csv('test.csv')
test
# Out:
#           id  person_age  person_income person_home_ownership  \
# 0      58645          23          69000                  RENT
# 1      58646          26          96000              MORTGAGE
# 2      58647          26          30000                  RENT
# 3      58648          33          50000                  RENT
# 4      58649          26         102000              MORTGAGE
# ...      ...         ...            ...                   ...
# 39093  97738          22          31200              MORTGAGE
# 39094  97739          22          48000              MORTGAGE
# 39095  97740          51          60000              MORTGAGE
# 39096  97741          22          36000              MORTGAGE
# 39097  97742          31          45000                  RENT
#
#        person_emp_length        loan_intent loan_grade  loan_amnt  \
# 0                    3.0    HOMEIMPROVEMENT          F      25000
# 1                    6.0           PERSONAL          C      10000
# ...

# %%
from sklearn.preprocessing import LabelEncoder
#for train data

le_th=LabelEncoder() #for home ownership
le_ti=LabelEncoder() #for loan intent
le_tg=LabelEncoder() #for loan grade
le_td=LabelEncoder() #for person on default file
train['owner']=le_th.fit_transform(train['person_home_ownership'])
train['intent']=le_ti.fit_transform(train['loan_intent'])
train['grade']=le_tg.fit_transform(train['loan_grade'])
train['default']=le_td.fit_transform(train['cb_person_default_on_file'])

#for test data
le_tth=LabelEncoder() #for home ownership
le_tti=LabelEncoder() #for loan intent
le_ttg=LabelEncoder() #for loan grade
le_ttd=LabelEncoder() #for person on default file
test['owner']=le_tth.fit_transform(test['person_home_ownership'])
test['intent']=le_tti.fit_transform(test['loan_intent'])
test['grade']=le_ttg.fit_transform(test['loan_grade'])
test['default']=le_ttd.fit_transform(test['cb_person_default_on_file'])

# %%
#Dropping columns not required anymore
target=train['loan_status']
train=train.drop(['person_home_ownership','loan_intent','loan_grade','cb_person_default_on_file','loan_status'],axis='columns')
test=test.drop(['person_home_ownership','loan_intent','loan_grade','cb_person_default_on_file'],axis='columns')

# %%
#Findng any NA values
print('TRAIN: \n',train.isna().any())
print('\n TEST: \n',test.isna().any())
# Out:
# TRAIN:
#  id                            False
# person_age                    False
# person_income                 False
# person_emp_length             False
# loan_amnt                     False
# loan_int_rate                 False
# loan_percent_income           False
# cb_person_cred_hist_length    False
# owner                         False
# intent                        False
# grade                         False
# default                       False
# dtype: bool
#
#  TEST:
#  id                            False
# person_age                    False
# person_income                 False
# person_emp_length             False
# loan_amnt                     False
# loan_int_rate                 False
# loan_percent_income           False
# cb_person_cred_hist_length    False
# owner                         False
# intent                        False
# grade                         False
# default                       False
# dtype: bool

# %%
#Finding model through hyperparametre tuning
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier

model_params={
    'RandomForest':{
        'model': RandomForestClassifier(),
        'params':{
            'n_estimators': [2,4,6,8]
        }
    },

    'LogisticRegression':{
        'model': LogisticRegression(solver='liblinear'),
        'params':{
            'C': [2,4,6,8]
        }
    },

    'GaussianNB':{
       'model': GaussianNB(),
        'params':{
            'var_smoothing': np.logspace(0,-9, num=100)

        }
    },

    'MultinomialNB':{
        'model': MultinomialNB(),
        'params':{

        }
    },

    'DecisionTreeClassifier':{'model': DecisionTreeClassifier(),
        'params':{
            'criterion': ['gini','entropy']
        }
    }


}

# %%
from sklearn.model_selection import GridSearchCV
scores=[]
for mn,mp in model_params.items():
  print(mn)
  print(mp)
  clf= GridSearchCV(mp['model'],mp['params'],cv=5,return_train_score=False)
  clf.fit(train,target)
  scores.append({
      'model':mn,
      'best_params':clf.best_params_,
      'best_score':clf.best_score_
  })
  df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# RandomForest
# {'model': RandomForestClassifier(), 'params': {'n_estimators': [2, 4, 6, 8]}}
# LogisticRegression
# {'model': LogisticRegression(solver='liblinear'), 'params': {'C': [2, 4, 6, 8]}}
# GaussianNB
# {'model': GaussianNB(), 'params': {'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5.33669923e-02, 4.32876128e-02,
#        3.51119173e-02, 2.84803587e-02, 2.31012970e-02, 1.87381742e-02,
#        1.51991108e-02, 1.23284674e-02, 1.00000000e-02, 8.11130831e-03,
#        6.57933225e-03, 5.33669923e-03, 4.32876128e-03, 3.51119173e-03,
#        2.84803587e-03, 2.31012970e-03, 1.87381742e-03, 1.51991108e-03,
#        1.23284674e-03, 1.00000000e-03, 8.11130831e-04, 6.57933225e-04,
#        5.33669923e-04, 4.32876128e-04, 3.51119173e-04, 2.84803587e-04,
# ...

# %%
model=RandomForestClassifier(n_estimators=2)
model.fit(train,target)
model.score(train,target)
# Out:
# 0.9698013470884134

# %%
y_pred= model.predict(test)

# %%
final=pd.DataFrame()
final['id']=test['id']
final['loan_status']=y_pred
final
# Out:
#           id  loan_status
# 0      58645            0
# 1      58646            0
# 2      58647            0
# 3      58648            0
# 4      58649            0
# ...      ...          ...
# 39093  97738            0
# 39094  97739            0
# 39095  97740            0
# 39096  97741            0
# 39097  97742            1
#
# [39098 rows x 2 columns]

# %%
final.to_csv('loan_approval.csv')
